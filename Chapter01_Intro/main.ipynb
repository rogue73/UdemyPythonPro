# %% [markdown]
# # Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Zwei mal Print

# %%
print("Hello Python")
print("Test")
# Out:
# Hello Python
# Test

# %%
import sys

print(sys.version)

print(sys.version_info)

print(sys.platform)
# Out:
# 3.12.10 (main, Apr 27 2025, 17:48:51) [GCC 12.2.0]
# sys.version_info(major=3, minor=12, micro=10, releaselevel='final', serial=0)
# linux
